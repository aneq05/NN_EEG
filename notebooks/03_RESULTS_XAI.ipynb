# %% [markdown]
# # 03 Results, uncertainty and XAI
#
# Notebook pomocniczy do przegladu kalibracji, niepewnosci, PFI i LIME.

# %%
import pandas as pd
display(pd.read_csv('../outputs/tables/pfi_segments_test.csv'))
display(pd.read_csv('../outputs/tables/lime_global.csv'))
# Out:
#      segment  importance_mean
# 0     X1-X30         0.659125
# 1    X61-X90         0.558005
# 2   X91-X120         0.533333
# 3    X31-X60         0.526675
# 4  X121-X150         0.523498
# 5  X151-X178         0.493125
#   feature  mean_abs_lime_weight
# 0      X7              0.001695
# 1      X4              0.001674
# 2      X1              0.001664
# 3      X9              0.001656
# 4      X8              0.001639
# 5      X2              0.001631
# 6      X3              0.001612
# 7      X6              0.001519
# 8      X5              0.001489

# %%
from IPython.display import Image, display
for path in ['../outputs/figures/reliability_diagram.png', '../outputs/figures/pfi_segments_test.png', '../outputs/figures/lime_global.png']:
    display(Image(path))

# %%
pd.read_csv('../outputs/tables/most_uncertain_wrong.csv').head()
# Out:
#    index  true  pred  correct  max_probability   entropy  margin_top1_top2
# 0    974     1     3    False         0.331503  1.456110          0.023803
# 1    747     3     4    False         0.330405  1.375937          0.004093
# 2   1148     1     4    False         0.392928  1.359056          0.100769
# 3   1195     2     4    False         0.380458  1.343815          0.056243
# 4    628     1     2    False         0.358317  1.329928          0.024209

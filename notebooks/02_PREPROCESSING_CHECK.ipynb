# %% [markdown]
# # 02 Preprocessing and training check
#
# Notebook pomocniczy do kontroli splitu, Optuny i metryk.

# %%
import pandas as pd
pd.read_csv('../outputs/tables/hyperparameter_search.csv')
# Out:
#    number     value              datetime_start           datetime_complete  \
# 0       0  0.617357  2026-06-20 13:15:51.981703  2026-06-20 13:16:04.950406
# 1       1  0.621649  2026-06-20 13:16:04.952417  2026-06-20 13:16:19.737612
# 2       2  0.620186  2026-06-20 13:16:19.739618  2026-06-20 13:16:26.600310
# 3       3  0.688974  2026-06-20 13:16:26.600310  2026-06-20 13:16:47.829239
# 4       4  0.637790  2026-06-20 13:16:47.829239  2026-06-20 13:17:03.673032
#
#                  duration params_architecture  params_dropout  \
# 0  0 days 00:00:12.968703               small             0.5
# 1  0 days 00:00:14.785195               large             0.5
# 2  0 days 00:00:06.860692               small             0.4
# 3  0 days 00:00:21.228929               large             0.2
# 4  0 days 00:00:15.843793               small             0.3
#
#    params_learning_rate  params_weight_decay     state
# 0              0.002318             0.000009  COMPLETE
# ...

# %%
pd.read_csv('../outputs/metrics/test_metrics.csv')
# Out:
#                 stage  accuracy  balanced_accuracy  macro_f1  weighted_f1  \
# 0  before_calibration      0.72               0.72  0.717677     0.717677
# 1   after_calibration      0.72               0.72  0.717677     0.717677
#
#         nll     brier       ece  macro_ovr_auroc
# 0  0.601797  0.356825  0.025256         0.938900
# 1  0.601492  0.356446  0.030758         0.938878

# %%
from IPython.display import Image
Image('../outputs/figures/confusion_matrix.png')

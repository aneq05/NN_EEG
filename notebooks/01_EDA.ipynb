# %% [markdown]
# # 01 EDA - EEG multiclass dataset
#
# Notebook pomocniczy do przegladu danych i wykresow wygenerowanych przez pipeline.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/data.csv')
df.shape, df['y'].value_counts().sort_index()
# Out:
# ((11500, 180),
#  y
#  1    2300
#  2    2300
#  3    2300
#  4    2300
#  5    2300
#  Name: count, dtype: int64)

# %%
from IPython.display import Image, display
for path in ['../outputs/figures/class_distribution.png', '../outputs/figures/example_signals.png', '../outputs/figures/mean_signals.png', '../outputs/figures/pca_train.png']:
    display(Image(path))
